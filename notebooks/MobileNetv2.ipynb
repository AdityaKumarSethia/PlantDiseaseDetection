# %% [markdown]
# # Plant Disease Detection using MobileNetv4
#
# - **Dataset** : New Plant Diseases Dataset
#     - *Author of Dateset* : Samir Bhattarai
#     - *Link* : [DataSet](https://www.kaggle.com/datasets/vipoooool/new-plant-diseases-dataset)
#
# - **Architecture** : MobileNetv2

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import tensorflow.keras as keras
# Out:
# 2025-11-16 09:41:30.494772: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763286090.574522     862 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763286090.599485     862 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-16 09:41:30.949939: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# --- CONSTANTS ---
IMG_SIZE = 224 # This is the standard input size for MobileNetV2
BATCH_SIZE = 32
NUM_CLASSES = 38
EPOCHS = 100 
TRAIN_DIR = "/mnt/d/College/DL/PlantDiseaseDetection-Project/New Plant Diseases Dataset(Augmented)/train"
VALID_DIR = "/mnt/d/College/DL/PlantDiseaseDetection-Project/New Plant Diseases Dataset(Augmented)/valid"

# %% [markdown]
# ## Data Loading and Augumentation

# %%
# Load the training data
train_ds = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    label_mode='int', # Your labels will be integers (0-37)
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE
)

# Load the validation data
valid_ds = tf.keras.utils.image_dataset_from_directory(
    VALID_DIR,
    label_mode='int',
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE
)

# Get the class names for later
class_names = train_ds.class_names
print(f"Found {len(class_names)} classes: {class_names}...")
# Out:
# Found 70295 files belonging to 38 classes.
# I0000 00:00:1763286168.399620     862 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5561 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Found 17572 files belonging to 38 classes.
# Found 38 classes: ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy', 'Blueberry___healthy', 'Cherry_(including_sour)___Powdery_mildew', 'Cherry_(including_sour)___healthy', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Corn_(maize)___Common_rust_', 'Corn_(maize)___Northern_Leaf_Blight', 'Corn_(maize)___healthy', 'Grape___Black_rot', 'Grape___Esca_(Black_Measles)', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Grape___healthy', 'Orange___Haunglongbing_(Citrus_greening)', 'Peach___Bacterial_spot', 'Peach___healthy', 'Pepper,_bell___Bacterial_spot', 'Pepper,_bell___healthy', 'Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy', 'Raspberry___healthy', 'Soybean___healthy', 'Squash___Powdery_mildew', 'Strawberry___Leaf_scorch', 'Strawberry___healthy', 'Tomato___Bacterial_spot', 'Tomato___Early_blight', 'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Target_Spot', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Tomato_mosaic_virus', 'Tomato___healthy']...

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.2),
    tf.keras.layers.RandomZoom(0.1),
    # Note: Rescaling (1./255) will be the VERY first layer in our final model
], name="data_augmentation")

# %% [markdown]
# ## PipeLine

# %%
# Set AUTOTUNE to let TensorFlow find the best number of parallel calls
AUTOTUNE = tf.data.AUTOTUNE

# --- Create the full, optimized pipelines ---

def preprocess(image, label):
    # Apply augmentation to the batch
    image = data_augmentation(image)
    return image, label

train_ds = train_ds.map(preprocess, num_parallel_calls=AUTOTUNE)
train_ds = train_ds.cache("my_train_cache").prefetch(buffer_size=AUTOTUNE) # <-- CHANGE THIS LINE

# Optimize the validation dataset
# This caches to a disk file named "my_valid_cache"
valid_ds = valid_ds.cache("my_valid_cache").prefetch(buffer_size=AUTOTUNE) # <-- CHANGE THIS LINE

# %%
from keras import layers, Model

# We use ReLU(6.0) as the activation, just like the original paper
# This helps with quantization (making the model work better on mobile)
relu6 = layers.ReLU(6.0)

def inverted_residual_block(
    x,               # Input tensor
    expansion_factor,  # How much to expand channels (e.g., 6)
    out_channels,    # Number of output channels
    strides,         # Stride for the depthwise conv (1 or 2)
):
    """
    Creates the MobileNetV2 Inverted Residual Block.
    """
    # Get the input channel count
    input_channels = x.shape[-1]
    
    # Calculate the number of channels for the "expansion" layer
    expanded_channels = input_channels * expansion_factor
    
    # Store the input for the residual connection
    shortcut = x

    # 1. --- Expansion (Pointwise) ---
    # Only expand if the expansion factor is not 1 (for the very first block)
    if expansion_factor != 1:
        x = layers.Conv2D(
            expanded_channels,
            (1, 1),
            padding='same',
            use_bias=False # No bias needed since we use Batch Norm
        )(x)
        x = layers.BatchNormalization()(x)
        x = relu6(x)

    # 2. --- Depthwise Convolution (Filtering) ---
    x = layers.DepthwiseConv2D(
        (3, 3),
        strides=strides,
        padding='same',
        use_bias=False
    )(x)
    x = layers.BatchNormalization()(x)
    x = relu6(x)

    # 3. --- Projection (Pointwise, Linear Bottleneck) ---
    x = layers.Conv2D(
        out_channels,
        (1, 1),
        padding='same',
        use_bias=False
    )(x)
    x = layers.BatchNormalization()(x)
    # --- Note: NO ACTIVATION HERE! This is the linear bottleneck. ---

    # 4. --- Residual Connection ---
    # We can only add the shortcut if:
    #   a) The stride is 1 (so spatial dimensions match)
    #   b) The input and output channels are the same
    if strides == 1 and input_channels == out_channels:
        x = layers.Add()([shortcut, x])
        
    return x

# %%
def create_mobilenet_v2(input_shape, num_classes):
    """
    Creates a full MobileNetV2 model from scratch.
    """
    inputs = layers.Input(shape=input_shape)

    # --- Rescaling Layer ---
    # This is a best practice. It scales [0-255] to [0-1].
    # It will run on the GPU as part of the model.
    x = layers.Rescaling(1./255)(inputs)
    
    # --- Stem (The first layer) ---
    x = layers.Conv2D(32, (3, 3), strides=2, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = relu6(x)

    # --- Body (The stack of inverted residual blocks) ---
    # We follow the table from the paper:
    # t = expansion_factor, c = out_channels, n = repeats, s = stride
    
    # t=1, c=16, n=1, s=1
    x = inverted_residual_block(x, 1, 16, 1)

    # t=6, c=24, n=2, s=2
    x = inverted_residual_block(x, 6, 24, 2)
    x = inverted_residual_block(x, 6, 24, 1)

    # t=6, c=32, n=3, s=2
    x = inverted_residual_block(x, 6, 32, 2)
    x = inverted_residual_block(x, 6, 32, 1)
    x = inverted_residual_block(x, 6, 32, 1)

    # t=6, c=64, n=4, s=2
    x = inverted_residual_block(x, 6, 64, 2)
    x = inverted_residual_block(x, 6, 64, 1)
    x = inverted_residual_block(x, 6, 64, 1)
    x = inverted_residual_block(x, 6, 64, 1)

    # t=6, c=96, n=3, s=1
    x = inverted_residual_block(x, 6, 96, 1)
    x = inverted_residual_block(x, 6, 96, 1)
    x = inverted_residual_block(x, 6, 96, 1)

    # t=6, c=160, n=3, s=2
    x = inverted_residual_block(x, 6, 160, 2)
    x = inverted_residual_block(x, 6, 160, 1)
    x = inverted_residual_block(x, 6, 160, 1)

    # t=6, c=320, n=1, s=1
    x = inverted_residual_block(x, 6, 320, 1)
    
    # --- Head (The final layers before classification) ---
    x = layers.Conv2D(1280, (1, 1), padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = relu6(x)
    
    # --- Classifier ---
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.2)(x) # Add dropout for regularization
    
    # Final output layer
    # We use 'softmax' for multi-class classification
    # We also specify dtype='float32' for numerical stability with mixed precision
    outputs = layers.Dense(num_classes, activation='softmax', dtype='float32')(x)
    
    # Create the model
    model = Model(inputs=inputs, outputs=outputs)
    
    return model

# %% [markdown]
# ## Model Creation

# %%
# Create the model
model = create_mobilenet_v2(
    input_shape=(IMG_SIZE, IMG_SIZE, 3), 
    num_classes=NUM_CLASSES
)

# Print the model summary
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 224, 224,  │          0 │ input_layer_1[0]… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 112, 112,  │        864 │ rescaling[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 112, 112,  │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 7, 7,      │          0 │ batch_normalizat… │
# │                     │ 1280)             │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d    │ (None, 112, 112,  │        288 │ re_lu[0][0]       │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 112, 112,  │        128 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 112, 112,  │        512 │ re_lu[1][0]       │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 112, 112,  │         64 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 112, 112,  │      1,536 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 112, 112,  │        384 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_1  │ (None, 56, 56,    │        864 │ re_lu[2][0]       │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        384 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 56, 56,    │      2,304 │ re_lu[3][0]       │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │         96 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 56, 56,    │      3,456 │ batch_normalizat… │
# │                     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        576 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_2  │ (None, 56, 56,    │      1,296 │ re_lu[4][0]       │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        576 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 56, 56,    │      3,456 │ re_lu[5][0]       │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │         96 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 56, 56,    │      3,456 │ add[0][0]         │
# │                     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        576 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_3  │ (None, 28, 28,    │      1,296 │ re_lu[6][0]       │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        576 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 28, 28,    │      4,608 │ re_lu[7][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        128 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 28, 28,    │      6,144 │ batch_normalizat… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        768 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4  │ (None, 28, 28,    │      1,728 │ re_lu[8][0]       │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        768 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 28, 28,    │      6,144 │ re_lu[9][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        128 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 28, 28,    │      6,144 │ add_1[0][0]       │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        768 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_5  │ (None, 28, 28,    │      1,728 │ re_lu[10][0]      │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        768 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 28, 28,    │      6,144 │ re_lu[11][0]      │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        128 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 28, 28,    │          0 │ add_1[0][0],      │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 28, 28,    │      6,144 │ add_2[0][0]       │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        768 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_6  │ (None, 14, 14,    │      1,728 │ re_lu[12][0]      │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │        768 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 14, 14,    │     12,288 │ re_lu[13][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │        256 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 14, 14,    │     24,576 │ batch_normalizat… │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,536 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_7  │ (None, 14, 14,    │      3,456 │ re_lu[14][0]      │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,536 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 14, 14,    │     24,576 │ re_lu[15][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │        256 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 14, 14,    │     24,576 │ add_3[0][0]       │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,536 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_8  │ (None, 14, 14,    │      3,456 │ re_lu[16][0]      │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,536 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 14, 14,    │     24,576 │ re_lu[17][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │        256 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 14, 14,    │          0 │ add_3[0][0],      │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 14, 14,    │     24,576 │ add_4[0][0]       │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,536 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_9  │ (None, 14, 14,    │      3,456 │ re_lu[18][0]      │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,536 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 14, 14,    │     24,576 │ re_lu[19][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │        256 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 14, 14,    │          0 │ add_4[0][0],      │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 14, 14,    │     24,576 │ add_5[0][0]       │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,536 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_10 │ (None, 14, 14,    │      3,456 │ re_lu[20][0]      │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,536 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 14, 14,    │     36,864 │ re_lu[21][0]      │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │        384 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 14, 14,    │     55,296 │ batch_normalizat… │
# │                     │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      2,304 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_11 │ (None, 14, 14,    │      5,184 │ re_lu[22][0]      │
# │ (DepthwiseConv2D)   │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      2,304 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 14, 14,    │     55,296 │ re_lu[23][0]      │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │        384 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 14, 14,    │     55,296 │ add_6[0][0]       │
# │                     │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      2,304 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_12 │ (None, 14, 14,    │      5,184 │ re_lu[24][0]      │
# │ (DepthwiseConv2D)   │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      2,304 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 14, 14,    │     55,296 │ re_lu[25][0]      │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │        384 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 14, 14,    │          0 │ add_6[0][0],      │
# │                     │ 96)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 14, 14,    │     55,296 │ add_7[0][0]       │
# │                     │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      2,304 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_13 │ (None, 7, 7, 576) │      5,184 │ re_lu[26][0]      │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 576) │      2,304 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 7, 7, 160) │     92,160 │ re_lu[27][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 160) │        640 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 7, 7, 960) │    153,600 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 960) │      3,840 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_14 │ (None, 7, 7, 960) │      8,640 │ re_lu[28][0]      │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 960) │      3,840 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 7, 7, 160) │    153,600 │ re_lu[29][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 160) │        640 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 7, 7, 160) │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 7, 7, 960) │    153,600 │ add_8[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 960) │      3,840 │ conv2d_30[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_15 │ (None, 7, 7, 960) │      8,640 │ re_lu[30][0]      │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 960) │      3,840 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 7, 7, 160) │    153,600 │ re_lu[31][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 160) │        640 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 7, 7, 160) │          0 │ add_8[0][0],      │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 7, 7, 960) │    153,600 │ add_9[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 960) │      3,840 │ conv2d_32[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_16 │ (None, 7, 7, 960) │      8,640 │ re_lu[32][0]      │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 960) │      3,840 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 7, 7, 320) │    307,200 │ re_lu[33][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 320) │      1,280 │ conv2d_33[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 7, 7,      │    409,600 │ batch_normalizat… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7,      │      5,120 │ conv2d_34[0][0]   │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ re_lu[34][0]      │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 1280)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 38)        │     48,678 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,306,662 (8.80 MB)
#  Trainable params: 2,272,550 (8.67 MB)
#  Non-trainable params: 34,112 (133.25 KB)

# %% [markdown]
# ## Compiling the Model with Mixed Precision for GPU Efficency

# %%
# Enable mixed precision
tf.keras.mixed_precision.set_global_policy('mixed_float16')

# %%
# Create an Adam optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)

# Compile the model
model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy']
)

print("Model compiled successfully with mixed precision enabled.")
# Out:
# Model compiled successfully with mixed precision enabled.

# %%
# --- 1. Best Model Checkpoint ---
# Saves the complete model, only when validation accuracy improves.
best_model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath="/mnt/d/College/DL/PlantDiseaseDetection-Project/models/mobilenetv2_from_scratch.keras", # The final, best model
    monitor="val_accuracy",
    save_best_only=True,
    verbose=1
)

# --- 2. Disaster Recovery Checkpoint ---
# Saves *only the weights* at the end of every single epoch.
# This is fast and ensures you can always resume from the last epoch.
latest_weights_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath="/mnt/d/College/DL/PlantDiseaseDetection-Project/models/checkpoints/mobilenetv2_latest.weights.h5", # Note: .h5 is standard for weights
    monitor="val_loss",
    save_weights_only=True,  # This is the key difference
    save_best_only=False,    # We want the *latest*, not the best
    verbose=0                # No need to print every epoch
)

# --- 3. EarlyStopping ---
# This is the same as before.
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=10,
    restore_best_weights=True
)

# --- 4. Create the *new* list of callbacks ---
callbacks_list = [
    best_model_checkpoint,
    latest_weights_checkpoint,
    early_stopping_callback
]

# --- How to resume (IF it crashes) ---
# 1. Re-create your model (run the `create_mobilenet_v2` function)
# 2. Compile it (run the `model.compile()` cell)
# 3. Load the latest weights:
#    model.load_weights("mobilenetv2_latest.weights.h5")
# 4. Re-run `model.fit()` to continue training

# %%
from tqdm.keras import TqdmCallback # Make sure this is imported

final_callbacks_list = [
    best_model_checkpoint,
    latest_weights_checkpoint,
    early_stopping_callback,
    TqdmCallback(verbose=0) # The clean epoch-only progress bar
]

# ---  Start Training! ---
print("Starting model training...")
print(f"Training on {NUM_CLASSES} classes for {EPOCHS} max epochs.")
print("The TQDM progress bar will show epoch-by-epoch progress.")

history = model.fit(
    train_ds,
    validation_data=valid_ds,
    epochs=EPOCHS,
    callbacks=final_callbacks_list,
    verbose=2  
)

print("-----------------------------------")
print("      TRAINING COMPLETE!           ")
print("-----------------------------------")
# Out:
# 0epoch [00:00, ?epoch/s]
# Starting model training...
# Training on 38 classes for 100 max epochs.
# The TQDM progress bar will show epoch-by-epoch progress.
# Epoch 1/100
# I0000 00:00:1763286196.913151    1083 service.cc:148] XLA service 0x757ad0005ae0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1763286196.913225    1083 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Laptop GPU, Compute Capability 8.9
# 2025-11-16 09:43:18.014982: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1763286200.103879    1083 cuda_dnn.cc:529] Loaded cuDNN version 90101
# 2025-11-16 09:44:01.721199: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng28{k2=1,k3=0} for conv (f32[32,96,112,112]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,16,112,112]{3,2,1,0}, f32[96,16,1,1]{3,2,1,0}), window={size=1x1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-11-16 09:44:01.723223: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 36.394263618s
# Trying algorithm eng28{k2=1,k3=0} for conv (f32[32,96,112,112]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,16,112,112]{3,2,1,0}, f32[96,16,1,1]{3,2,1,0}), window={size=1x1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-11-16 09:44:06.723930: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng28{k2=4,k3=0} for conv (f32[32,96,112,112]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,96,114,114]{3,2,1,0}, f32[96,1,3,3]{3,2,1,0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, feature_group_count=96, custom_call_target="__cudnn$convForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-11-16 09:44:06.731994: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 36.440912357s
# Trying algorithm eng28{k2=4,k3=0} for conv (f32[32,96,112,112]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,96,114,114]{3,2,1,0}, f32[96,1,3,3]{3,2,1,0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, feature_group_count=96, custom_call_target="__cudnn$convForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-11-16 09:44:11.732026: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng18{k11=0} for conv (f32[576,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,576,14,14]{3,2,1,0}, f32[32,576,14,14]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=576, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# I0000 00:00:1763286225.609624    1083 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-11-16 09:53:45.525236: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_13283', 32 bytes spill stores, 32 bytes spill loads
#
# 2025-11-16 09:54:22.471896: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng53{k2=8,k13=1,k14=3,k18=0,k23=0} for conv (f32[23,32,112,112]{3,2,1,0}, u8[0]{0}) custom-call(f32[23,3,225,225]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}), window={size=3x3 stride=2x2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-11-16 09:54:22.473663: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 36.427375149s
# Trying algorithm eng53{k2=8,k13=1,k14=3,k18=0,k23=0} for conv (f32[23,32,112,112]{3,2,1,0}, u8[0]{0}) custom-call(f32[23,3,225,225]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}), window={size=3x3 stride=2x2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-11-16 09:54:27.477922: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng34{k2=2,k4=0,k5=0,k6=0,k7=0,k19=0} for conv (f32[23,96,112,112]{3,2,1,0}, u8[0]{0}) custom-call(f32[23,96,114,114]{3,2,1,0}, f32[96,1,3,3]{3,2,1,0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, feature_group_count=96, custom_call_target="__cudnn$convForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-11-16 09:54:27.506896: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 36.456864152s
# Trying algorithm eng34{k2=2,k4=0,k5=0,k6=0,k7=0,k19=0} for conv (f32[23,96,112,112]{3,2,1,0}, u8[0]{0}) custom-call(f32[23,96,114,114]{3,2,1,0}, f32[96,1,3,3]{3,2,1,0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, feature_group_count=96, custom_call_target="__cudnn$convForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-11-16 09:54:07.452494: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1165', 144 bytes spill stores, 144 bytes spill loads
#
# 2025-11-16 09:54:07.536321: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1165', 520 bytes spill stores, 520 bytes spill loads
# Epoch 1: val_accuracy improved from None to 0.35488, saving model to /mnt/d/College/DL/PlantDiseaseDetection-Project/models/mobilenetv2_from_scratch.keras
# 2025-11-16 09:56:35.638939: W tensorflow/core/kernels/data/cache_dataset_ops.cc:332] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.
# 2197/2197 - 817s - 372ms/step - accuracy: 0.6405 - loss: 1.1799 - val_accuracy: 0.3549 - val_loss: 5.1028
# Epoch 2/100
# 2025-11-16 09:56:37.095025: W tensorflow/core/kernels/data/cache_dataset_ops.cc:332] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.
# Epoch 2: val_accuracy improved from 0.35488 to 0.73185, saving model to /mnt/d/College/DL/PlantDiseaseDetection-Project/models/mobilenetv2_from_scratch.keras
# 2197/2197 - 460s - 209ms/step - accuracy: 0.8621 - loss: 0.4209 - val_accuracy: 0.7318 - val_loss: 1.0069
# Epoch 3/100
#
# Epoch 3: val_accuracy improved from 0.73185 to 0.83673, saving model to /mnt/d/College/DL/PlantDiseaseDetection-Project/models/mobilenetv2_from_scratch.keras
# 2197/2197 - 458s - 209ms/step - accuracy: 0.9116 - loss: 0.2687 - val_accuracy: 0.8367 - val_loss: 0.5799
# Epoch 4/100
#
# Epoch 4: val_accuracy did not improve from 0.83673
# 2197/2197 - 458s - 208ms/step - accuracy: 0.9353 - loss: 0.1942 - val_accuracy: 0.7412 - val_loss: 1.1294
# Epoch 5/100
#
# Epoch 5: val_accuracy improved from 0.83673 to 0.86000, saving model to /mnt/d/College/DL/PlantDiseaseDetection-Project/models/mobilenetv2_from_scratch.keras
# 2197/2197 - 449s - 204ms/step - accuracy: 0.9501 - loss: 0.1481 - val_accuracy: 0.8600 - val_loss: 0.4904
# Epoch 6/100
#
# Epoch 6: val_accuracy did not improve from 0.86000
# 2197/2197 - 443s - 202ms/step - accuracy: 0.9592 - loss: 0.1197 - val_accuracy: 0.7604 - val_loss: 1.1835
# Epoch 7/100
#
# Epoch 7: val_accuracy did not improve from 0.86000
# 2197/2197 - 435s - 198ms/step - accuracy: 0.9667 - loss: 0.1003 - val_accuracy: 0.7575 - val_loss: 1.4122
# Epoch 8/100
#
# Epoch 8: val_accuracy did not improve from 0.86000
# 2197/2197 - 437s - 199ms/step - accuracy: 0.9712 - loss: 0.0842 - val_accuracy: 0.7581 - val_loss: 1.2791
# Epoch 9/100
#
# Epoch 9: val_accuracy did not improve from 0.86000
# 2197/2197 - 436s - 198ms/step - accuracy: 0.9750 - loss: 0.0736 - val_accuracy: 0.7981 - val_loss: 1.0422
# Epoch 10/100
#
# Epoch 10: val_accuracy did not improve from 0.86000
# 2197/2197 - 444s - 202ms/step - accuracy: 0.9788 - loss: 0.0629 - val_accuracy: 0.8445 - val_loss: 0.6421
# Epoch 11/100
#
# Epoch 11: val_accuracy improved from 0.86000 to 0.86160, saving model to /mnt/d/College/DL/PlantDiseaseDetection-Project/models/mobilenetv2_from_scratch.keras
# 2197/2197 - 439s - 200ms/step - accuracy: 0.9801 - loss: 0.0564 - val_accuracy: 0.8616 - val_loss: 0.6151
# Epoch 12/100
#
# Epoch 12: val_accuracy did not improve from 0.86160
# 2197/2197 - 445s - 203ms/step - accuracy: 0.9830 - loss: 0.0502 - val_accuracy: 0.7148 - val_loss: 1.9245
# Epoch 13/100
#
# Epoch 13: val_accuracy improved from 0.86160 to 0.93962, saving model to /mnt/d/College/DL/PlantDiseaseDetection-Project/models/mobilenetv2_from_scratch.keras
# 2197/2197 - 438s - 199ms/step - accuracy: 0.9837 - loss: 0.0477 - val_accuracy: 0.9396 - val_loss: 0.2482
# Epoch 14/100
#
# Epoch 14: val_accuracy did not improve from 0.93962
# 2197/2197 - 445s - 202ms/step - accuracy: 0.9854 - loss: 0.0423 - val_accuracy: 0.9330 - val_loss: 0.2690
# Epoch 15/100
#
# Epoch 15: val_accuracy did not improve from 0.93962
# 2197/2197 - 438s - 199ms/step - accuracy: 0.9869 - loss: 0.0384 - val_accuracy: 0.8621 - val_loss: 0.8442
# Epoch 16/100
#
# Epoch 16: val_accuracy improved from 0.93962 to 0.95692, saving model to /mnt/d/College/DL/PlantDiseaseDetection-Project/models/mobilenetv2_from_scratch.keras
# 2197/2197 - 435s - 198ms/step - accuracy: 0.9881 - loss: 0.0335 - val_accuracy: 0.9569 - val_loss: 0.1718
# Epoch 17/100
#
# Epoch 17: val_accuracy did not improve from 0.95692
# 2197/2197 - 436s - 199ms/step - accuracy: 0.9884 - loss: 0.0341 - val_accuracy: 0.9430 - val_loss: 0.2429
# Epoch 18/100
#
# Epoch 18: val_accuracy did not improve from 0.95692
# 2197/2197 - 439s - 200ms/step - accuracy: 0.9890 - loss: 0.0323 - val_accuracy: 0.9073 - val_loss: 0.5082
# Epoch 19/100
#
# Epoch 19: val_accuracy did not improve from 0.95692
# 2197/2197 - 439s - 200ms/step - accuracy: 0.9908 - loss: 0.0283 - val_accuracy: 0.9271 - val_loss: 0.3542
# Epoch 20/100
#
# Epoch 20: val_accuracy did not improve from 0.95692
# 2197/2197 - 431s - 196ms/step - accuracy: 0.9902 - loss: 0.0300 - val_accuracy: 0.8868 - val_loss: 0.5181
# Epoch 21/100
#
# Epoch 21: val_accuracy did not improve from 0.95692
# 2197/2197 - 428s - 195ms/step - accuracy: 0.9914 - loss: 0.0256 - val_accuracy: 0.8951 - val_loss: 0.4680
# Epoch 22/100
#
# Epoch 22: val_accuracy did not improve from 0.95692
# 2197/2197 - 460s - 209ms/step - accuracy: 0.9918 - loss: 0.0242 - val_accuracy: 0.9550 - val_loss: 0.1736
# Epoch 23/100
#
# Epoch 23: val_accuracy improved from 0.95692 to 0.96483, saving model to /mnt/d/College/DL/PlantDiseaseDetection-Project/models/mobilenetv2_from_scratch.keras
# 2197/2197 - 431s - 196ms/step - accuracy: 0.9919 - loss: 0.0248 - val_accuracy: 0.9648 - val_loss: 0.1309
# Epoch 24/100
#
# Epoch 24: val_accuracy improved from 0.96483 to 0.96711, saving model to /mnt/d/College/DL/PlantDiseaseDetection-Project/models/mobilenetv2_from_scratch.keras
# 2197/2197 - 484s - 220ms/step - accuracy: 0.9923 - loss: 0.0240 - val_accuracy: 0.9671 - val_loss: 0.1282
# Epoch 25/100
#
# Epoch 25: val_accuracy did not improve from 0.96711
# 2197/2197 - 400s - 182ms/step - accuracy: 0.9929 - loss: 0.0209 - val_accuracy: 0.9624 - val_loss: 0.1457
# Epoch 26/100
#
# Epoch 26: val_accuracy did not improve from 0.96711
# 2197/2197 - 444s - 202ms/step - accuracy: 0.9926 - loss: 0.0217 - val_accuracy: 0.9564 - val_loss: 0.1634
# Epoch 27/100
#
# Epoch 27: val_accuracy did not improve from 0.96711
# 2197/2197 - 440s - 200ms/step - accuracy: 0.9935 - loss: 0.0180 - val_accuracy: 0.8717 - val_loss: 0.6258
# Epoch 28/100
#
# Epoch 28: val_accuracy did not improve from 0.96711
# 2197/2197 - 441s - 201ms/step - accuracy: 0.9936 - loss: 0.0193 - val_accuracy: 0.8455 - val_loss: 0.8985
# Epoch 29/100
#
# Epoch 29: val_accuracy did not improve from 0.96711
# 2197/2197 - 449s - 205ms/step - accuracy: 0.9935 - loss: 0.0195 - val_accuracy: 0.9561 - val_loss: 0.2161
# Epoch 30/100
#
# Epoch 30: val_accuracy did not improve from 0.96711
# 2197/2197 - 444s - 202ms/step - accuracy: 0.9940 - loss: 0.0176 - val_accuracy: 0.9500 - val_loss: 0.2463
# Epoch 31/100
#
# Epoch 31: val_accuracy did not improve from 0.96711
# 2197/2197 - 447s - 203ms/step - accuracy: 0.9947 - loss: 0.0166 - val_accuracy: 0.9219 - val_loss: 0.4080
# Epoch 32/100
#
# Epoch 32: val_accuracy did not improve from 0.96711
# 2197/2197 - 444s - 202ms/step - accuracy: 0.9940 - loss: 0.0184 - val_accuracy: 0.8716 - val_loss: 0.6386
# Epoch 33/100
#
# Epoch 33: val_accuracy improved from 0.96711 to 0.96933, saving model to /mnt/d/College/DL/PlantDiseaseDetection-Project/models/mobilenetv2_from_scratch.keras
# 2197/2197 - 452s - 206ms/step - accuracy: 0.9952 - loss: 0.0138 - val_accuracy: 0.9693 - val_loss: 0.1175
# Epoch 34/100
#
# Epoch 34: val_accuracy improved from 0.96933 to 0.97695, saving model to /mnt/d/College/DL/PlantDiseaseDetection-Project/models/mobilenetv2_from_scratch.keras
# 2197/2197 - 452s - 206ms/step - accuracy: 0.9940 - loss: 0.0171 - val_accuracy: 0.9770 - val_loss: 0.0942
# Epoch 35/100
#
# Epoch 35: val_accuracy did not improve from 0.97695
# 2197/2197 - 452s - 206ms/step - accuracy: 0.9955 - loss: 0.0136 - val_accuracy: 0.9489 - val_loss: 0.2368
# Epoch 36/100
#
# Epoch 36: val_accuracy did not improve from 0.97695
# 2197/2197 - 436s - 198ms/step - accuracy: 0.9947 - loss: 0.0155 - val_accuracy: 0.9229 - val_loss: 0.4872
# Epoch 37/100
#
# Epoch 37: val_accuracy improved from 0.97695 to 0.97991, saving model to /mnt/d/College/DL/PlantDiseaseDetection-Project/models/mobilenetv2_from_scratch.keras
# 2197/2197 - 445s - 202ms/step - accuracy: 0.9956 - loss: 0.0137 - val_accuracy: 0.9799 - val_loss: 0.0769
# Epoch 38/100
#
# Epoch 38: val_accuracy improved from 0.97991 to 0.98395, saving model to /mnt/d/College/DL/PlantDiseaseDetection-Project/models/mobilenetv2_from_scratch.keras
# 2197/2197 - 481s - 219ms/step - accuracy: 0.9956 - loss: 0.0144 - val_accuracy: 0.9840 - val_loss: 0.0573
# Epoch 39/100
#
# Epoch 39: val_accuracy did not improve from 0.98395
# 2197/2197 - 399s - 182ms/step - accuracy: 0.9956 - loss: 0.0140 - val_accuracy: 0.9696 - val_loss: 0.1134
# Epoch 40/100
#
# Epoch 40: val_accuracy did not improve from 0.98395
# 2197/2197 - 444s - 202ms/step - accuracy: 0.9957 - loss: 0.0131 - val_accuracy: 0.9798 - val_loss: 0.0764
# Epoch 41/100
#
# Epoch 41: val_accuracy did not improve from 0.98395
# 2197/2197 - 439s - 200ms/step - accuracy: 0.9959 - loss: 0.0121 - val_accuracy: 0.9617 - val_loss: 0.1717
# Epoch 42/100
#
# Epoch 42: val_accuracy did not improve from 0.98395
# 2197/2197 - 429s - 195ms/step - accuracy: 0.9958 - loss: 0.0122 - val_accuracy: 0.9791 - val_loss: 0.0936
# Epoch 43/100
#
# Epoch 43: val_accuracy did not improve from 0.98395
# 2197/2197 - 442s - 201ms/step - accuracy: 0.9952 - loss: 0.0144 - val_accuracy: 0.9795 - val_loss: 0.0893
# Epoch 44/100
#
# Epoch 44: val_accuracy did not improve from 0.98395
# 2197/2197 - 442s - 201ms/step - accuracy: 0.9961 - loss: 0.0121 - val_accuracy: 0.8921 - val_loss: 0.6753
# Epoch 45/100
#
# Epoch 45: val_accuracy did not improve from 0.98395
# 2197/2197 - 432s - 197ms/step - accuracy: 0.9967 - loss: 0.0102 - val_accuracy: 0.8580 - val_loss: 0.7768
# Epoch 46/100
#
# Epoch 46: val_accuracy did not improve from 0.98395
# 2197/2197 - 442s - 201ms/step - accuracy: 0.9961 - loss: 0.0119 - val_accuracy: 0.9694 - val_loss: 0.1266
# Epoch 47/100
#
# Epoch 47: val_accuracy did not improve from 0.98395
# 2197/2197 - 431s - 196ms/step - accuracy: 0.9969 - loss: 0.0096 - val_accuracy: 0.9781 - val_loss: 0.0869
# Epoch 48/100
#
# Epoch 48: val_accuracy did not improve from 0.98395
# 2197/2197 - 431s - 196ms/step - accuracy: 0.9965 - loss: 0.0106 - val_accuracy: 0.9617 - val_loss: 0.1929
# -----------------------------------
#       TRAINING COMPLETE!
# -----------------------------------
